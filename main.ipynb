# %%
import qg_atm as qg

# %%
config = {
    'experiment': "acc-dissipation-free",
    'n_iter': 100,
    't_iter': 100,
    'descript': {
        'N': 256,
        'M': 2,
        'initial': 'random',
    },
    # 'first_state': "last",
    # 'print_dataset': "all",
    'print_state': "std",
    'pds_args': {
        'q_range': "end", 
        'u_range': "end", 
        'q_cmap':"balance"
    },
}

driver = qg.Driver(qg.Config(**config))
print(driver.devices)
# result = driver.run() 
ds = driver.postprocess()
# Out:
# [CpuDevice(id=0)]
#
# Preparing dataset...
# 100%|██████████| 10001/10001 [00:00<00:00, 10987.70it/s]

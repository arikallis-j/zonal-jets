# %%
from qg_atm import *
import matplotlib.pyplot as plt
import numpy as np

# %%
descript = {
    'N': 128,
    'M': 100,
    'nu': 1e-5,
    'initial': 'u-random',
}

config = Config(
    experiment="jupyter",
    descript=descript, 
    print_dataset="std", 
    pds_args={'q_cmap':"balance"},
)

driver = Driver(config)

# %%
result = driver.run(n_iter=100)
# Out:
# KE: 6.26e-03, VE: 6.36e-01 | time-iter =   2.24  s | 100/100 [03:47<00:00]
# Preparing dataset...
# 100%|██████████| 101/101 [00:00<00:00, 227.44it/s]
# Saving animation of q...
# Saving animation of u...
# Saving animation of e_spec...
# Saving animation of z_spec...
